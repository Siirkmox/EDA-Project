# %% [markdown]
# # 3. Análisis Exploratorio de Datos (EDA)
#
# Este notebook contiene el análisis visual y las conclusiones del proyecto de inversión en I+D en España.
#
# ## Objetivos del análisis
#
# 1. **Evolución temporal** del gasto total en I+D (2000-2024)
# 2. **Distribución sectorial** del gasto
# 3. **Análisis del origen** de los fondos
# 4. **Impacto de eventos económicos** (Crisis 2008, COVID-19)
# 5. **Conclusiones** y hallazgos principales
#
# ---
#
# **Input:**
# - `data/cleanedDataset/gastos_clean.csv` (generado por notebook 2)
# - `data/cleanedDataset/fondos_clean.csv` (generado por notebook 2)
#
# **Output:**
# - Visualizaciones y análisis
# - Conclusiones del estudio

# %%
# Importar librerías estándar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importar módulo de visualización personalizado
import sys
sys.path.append('../src')
from visualization import (
    configurar_estilo,
    plot_evolucion_temporal,
    plot_distribucion_sectorial,
    plot_origen_fondos,
    plot_impacto_eventos
)

print("✅ Librerías y módulos importados correctamente")
# Out:
# ✅ Librerías y módulos importados correctamente

# %%
# Cargar datasets limpios del notebook anterior
df_gastos_wide = pd.read_csv('../data/cleanedDataset/gastos_clean.csv', index_col='Años')
df_fondos_wide = pd.read_csv('../data/cleanedDataset/fondos_clean.csv', index_col='Años')

print("="*70)
print("DATASETS LIMPIOS CARGADOS")
print("="*70)
print(f"\n📊 Gastos I+D:")
print(f"   Dimensiones: {df_gastos_wide.shape}")
print(f"   Período: {df_gastos_wide.index.min():.0f} - {df_gastos_wide.index.max():.0f}")
print(f"   Columnas: {list(df_gastos_wide.columns)}")

print(f"\n📊 Fondos I+D:")
print(f"   Dimensiones: {df_fondos_wide.shape}")
print(f"   Período: {df_fondos_wide.index.min():.0f} - {df_fondos_wide.index.max():.0f}")
print(f"   Columnas: {list(df_fondos_wide.columns)}")

print("\n✅ Datos listos para análisis")
# Out:
# ...
# DATASETS LIMPIOS CARGADOS
# ...
#
# 📊 Gastos I+D:
#    Dimensiones: (25, 5)
#    Período: 2000 - 2024
#    Columnas: ['Admin_Publica', 'Empresas', 'Enseñanza_Superior', 'IPSFL', 'Total']
#
# 📊 Fondos I+D:
#    Dimensiones: (25, 5)
#    Período: 2000 - 2024
#    Columnas: ['Admin_Publica', 'Empresas', 'IPSFL', 'Resto_Mundo', 'Total']
#
# ✅ Datos listos para análisis

# %%
# Configurar estilo visual de los gráficos
configurar_estilo()
print("✅ Estilo de visualización configurado")
# Out:
# ✅ Estilo de visualización configurado

# %% [markdown]
# ## 7. Análisis y Visualizaciones
#
# En esta sección se presentan los análisis visuales que responden a los objetivos del proyecto.
#
# ### 7.1 Evolución temporal del gasto total en I+D (2000-2024)
#
# Analizamos cómo ha evolucionado la inversión total en I+D en España durante el período estudiado, identificando tendencias y puntos de inflexión.

# %%
# Visualización de la evolución temporal
plot_evolucion_temporal(df_gastos_wide)
# Out:
# ...
# ESTADÍSTICAS DEL GASTO TOTAL EN I+D (2000-2024)
# ...
#
# 💰 Gasto en 2000: 5,718,988 miles de €
# 💰 Gasto en 2024: 23,930,881 miles de €
#
# 📈 Crecimiento total: 318.4%
# 📊 Gasto máximo: 23,930,881 miles de € (año 2024.0)
# 📉 Gasto mínimo: 5,718,988 miles de € (año 2000.0)
#
# 📊 Media del período: 13,543,914 miles de €
# 📊 Desviación estándar: 4,417,034 miles de €

# %% [markdown]
# ### 7.2 Distribución del gasto por sectores
#
# Analizamos cómo se distribuye la inversión en I+D entre los diferentes sectores ejecutores:
# - Administración Pública
# - Enseñanza Superior
# - Empresas
# - IPSFL (Instituciones Privadas Sin Fines de Lucro)

# %%
# Visualización de la distribución sectorial
plot_distribucion_sectorial(df_gastos_wide)
# Out:
# ...
# ANÁLISIS POR SECTORES (2000 vs 2024)
# ...
#
# 📊 Admin Publica:
#    2000: 904,776 miles de €
#    2024: 4,564,779 miles de €
#    Crecimiento: +404.5%
#
# 📊 Enseñanza Superior:
#    2000: 1,693,882 miles de €
#    2024: 5,961,559 miles de €
#    Crecimiento: +251.9%
#
# 📊 Empresas:
#    2000: 3,068,994 miles de €
#    2024: 13,342,419 miles de €
#    Crecimiento: +334.7%
#
# 📊 Ipsfl:
#    2000: 51,336 miles de €
#    2024: 62,124 miles de €
#    Crecimiento: +21.0%

# %% [markdown]
# ### 7.3 Análisis del origen de los fondos
#
# Exploramos de dónde provienen los fondos que financian la I+D en España:
# - Administración Pública
# - Empresas
# - IPSFL
# - Resto del Mundo (financiación internacional)

# %%
# Visualización del origen de fondos
plot_origen_fondos(df_fondos_wide)
# Out:
# ...
# ORIGEN DE LOS FONDOS (2024)
# ...
#
# 💰 Admin Publica: 10,236,725 miles de € (42.8%)
#
# 💰 Empresas: 11,421,103 miles de € (47.7%)
#
# 💰 Ipsfl: 161,678 miles de € (0.7%)
#
# 💰 Resto Mundo: 2,111,374 miles de € (8.8%)

# %% [markdown]
# ### 7.4 Impacto de eventos económicos
#
# Analizamos el impacto de dos eventos económicos importantes en la inversión en I+D:
#
# 1. **Crisis Financiera de 2008**: ¿Cómo afectó la recesión económica a la inversión en I+D?
# 2. **Pandemia COVID-19 (2020)**: ¿Se mantuvo la inversión durante la crisis sanitaria?

# %%
# Visualización del impacto de eventos económicos
plot_impacto_eventos(df_gastos_wide)
# Out:
# ...
# IMPACTO DE LA CRISIS DE 2008
# ...
#
# 💰 Gasto en 2008: 14,701,393 miles de €
# 💰 Gasto en 2013 (punto más bajo): 13,011,798 miles de €
# 📉 Variación 2008-2013: -11.5%
#
# ...
# IMPACTO DE LA PANDEMIA COVID-19
# ...
#
# 💰 Gasto en 2019: 15,572,052 miles de €
# 💰 Gasto en 2020: 15,768,133 miles de €
# 💰 Gasto en 2021: 17,249,249 miles de €
# 📊 Variación 2019-2020: +1.3%
# 📈 Variación 2020-2021: +9.4%

# %% [markdown]
# ### 7.5 Distribución estadística del gasto en I+D
#
# Analizamos la distribución de frecuencias del gasto total y del crecimiento interanual mediante histogramas.

# %% [markdown]
# ### 7.5 Resumen del análisis visual
#
# **Principales hallazgos:**
#
# 1. **Tendencia general**: La inversión en I+D en España ha experimentado un crecimiento significativo en el período 2000-2024, aunque con fases de estancamiento.
#
# 2. **Distribución sectorial**:
#    - Las **Empresas** son el principal sector ejecutor del gasto en I+D (≈56% del total)
#    - La **Enseñanza Superior** ha incrementado significativamente su participación (≈25%)
#    - La **Administración Pública** mantiene una participación estable (≈17-19%)
#    - **IPSFL** mantiene una participación marginal pero estable (≈0.3%)
#
# 3. **Origen de fondos**:
#    - La financiación está repartida principalmente entre **Administración Pública** (≈43%) y **Empresas** (≈48%)
#    - El **Resto del Mundo** aporta cerca del 9% de los fondos, mostrando la internacionalización de la I+D española
#    - Las **IPSFL** contribuyen con aproximadamente 0.7%
#
# 4. **Impacto de eventos económicos**:
#    - La **Crisis de 2008** generó un estancamiento y posterior descenso del gasto (2008-2013)
#    - El punto más bajo se alcanzó en 2013, con una caída aproximada del 10% respecto a 2008
#    - La **Pandemia COVID-19** no detuvo la tendencia de crecimiento, mostrando mayor resiliencia
#    - Se observó una recuperación rápida en 2021 con crecimiento del 8-10%
#
# 5. **Recuperación reciente**:
#    - Desde 2014 se observa una recuperación sostenida
#    - Se alcanzaron máximos históricos en 2023-2024
#    - El crecimiento total del período 2000-2024 supera el 300%

# %% [markdown]
# ## 8. Conclusiones
#
# En este análisis exploratorio se ha realizado un estudio completo de la inversión en I+D en España durante el período 2000-2024, cumpliendo con los objetivos planteados inicialmente.
#
# ### 8.1 Resumen del proceso realizado
#
# **Pipeline completo de análisis:**
#
# 1. **Carga y verificación** (Notebook 1):
#    - Se trabajó con 4 datasets del INE (Instituto Nacional de Estadística)
#    - Datos de gastos y fondos de I+D con períodos 1964-2021 y 2021-2024
#    - Fuente de datos oficial y fiable
#
# 2. **Preparación y consolidación** (Notebook 1):
#    - Unificación de los 4 datasets en 2 (gastos y fondos)
#    - Eliminación del año duplicado (2021)
#    - Filtrado del período de interés: 2000-2024
#    - Normalización de tipos de datos
#
# 3. **Exploración y evaluación de calidad** (Notebook 1):
#    - Identificación de problemas: formato europeo, valores "..", mezcla de absolutos/porcentajes
#    - Análisis de estructura (formato largo vs ancho)
#    - Evaluación de valores nulos y duplicados
#
# 4. **Limpieza y transformación** (Notebook 2):
#    - Conversión de formato numérico europeo a estándar
#    - Tratamiento de valores faltantes (".." → NaN)
#    - Separación de valores absolutos y porcentajes
#    - Transformación de formato largo a ancho (pivot)
#    - Renombrado de columnas para mayor claridad
#    - Uso de funciones modulares del paquete `src/cleaning.py`
#
# 5. **Análisis y visualizaciones** (Notebook 3):
#    - Evolución temporal del gasto total en I+D
#    - Distribución sectorial del gasto
#    - Análisis del origen de los fondos
#    - Impacto de eventos económicos (crisis 2008, COVID-19)
#    - Uso de funciones modulares del paquete `src/visualization.py`

# %% [markdown]
# ### 8.2 Principales hallazgos
#
# **Evolución del gasto en I+D:**
# - **Crecimiento sostenido** desde 2000 hasta 2024, con incremento superior al 300%
# - El gasto pasó de aproximadamente 5.700 millones de € en 2000 a casi 24.000 millones de € en 2024
# - Máximo histórico alcanzado en 2024
#
# **Impacto de la Crisis de 2008:**
# - Estancamiento del crecimiento entre 2008-2009
# - **Descenso significativo** del gasto entre 2009-2013 (aproximadamente -10%)
# - El año 2013 marcó el punto más bajo del período post-crisis
# - Recuperación lenta que comenzó a partir de 2014
#
# **Impacto de la Pandemia COVID-19:**
# - A diferencia de la crisis de 2008, **no se produjo una caída** del gasto en I+D
# - Ligera desaceleración en 2020, pero manteniendo la tendencia positiva
# - Recuperación rápida en 2021 con crecimiento aproximado del 8-10%
# - Indica mayor resiliencia del sector I+D ante crisis sanitarias vs crisis financieras
#
# **Distribución sectorial:**
# - **Empresas**: Principal ejecutor del gasto (55-58% del total)
# - **Enseñanza Superior**: Segundo sector más importante (24-27%)
# - **Administración Pública**: Tercer lugar (17-19%)
# - **IPSFL**: Participación marginal pero estable (≈0.3%)
# - Todos los sectores han experimentado crecimiento en valores absolutos
#
# **Origen de los fondos:**
# - **Empresas** y **Administración Pública**: Principales fuentes de financiación (≈48% y ≈43% respectivamente)
# - **Resto del Mundo**: Contribución significativa y creciente (≈9% en 2024)
# - **IPSFL**: Aportación menor pero constante (≈0.7%)
# - Balance equilibrado entre financiación pública y privada

# %% [markdown]
# ### 8.3 Calidad de los datos
#
# **Fortalezas:**
# - ✅ Fuente oficial y fiable (INE - Instituto Nacional de Estadística)
# - ✅ Datos consistentes y bien estructurados
# - ✅ Cobertura temporal amplia (25 años para nuestro análisis)
# - ✅ Granularidad sectorial adecuada para el análisis
#
# **Limitaciones identificadas:**
# - ⚠️ Presencia de valores faltantes en años específicos (marcados como "..")
# - ⚠️ Formato numérico europeo que requirió conversión
# - ⚠️ Mezcla de valores absolutos y porcentajes en el mismo dataset
# - ⚠️ Cambio en la periodicidad de publicación (datasets separados por períodos)
# - ⚠️ Año 2021 duplicado en ambos conjuntos de datos
#
# **Decisiones de limpieza aplicadas:**
# - ✅ Conversión de ".." a NaN (mantener integridad de los datos)
# - ✅ Separación de valores absolutos y porcentajes
# - ✅ Transformación a formato ancho para análisis temporal
# - ✅ Mantenimiento de valores NaN (preferible a imputación arbitraria)
# - ✅ Uso de funciones modulares para reproducibilidad

# %% [markdown]
# ### 8.4 Objetivos cumplidos
#
# ✅ **Objetivo 1 - Evolución temporal del gasto en I+D**:
# - Se identificó claramente la tendencia de crecimiento con períodos de estancamiento
# - Se cuantificó el crecimiento total del período (>300%)
# - Se identificaron los años clave: máximos y mínimos
#
# ✅ **Objetivo 2 - Análisis sectorial**:
# - Se analizó la distribución del gasto por sectores
# - Se identificaron las Empresas como principal ejecutor (≈56%)
# - Se cuantificó el crecimiento de cada sector entre 2000 y 2024
# - Se visualizó la evolución temporal de cada sector
#
# ✅ **Objetivo 3 - Origen de los fondos**:
# - Se identificaron las principales fuentes de financiación
# - Se analizó la evolución de la financiación por origen
# - Se cuantificó la participación de cada fuente en 2024
# - Se identificó el balance público-privado (≈50-50)
#
# ✅ **Objetivo 4 - Impacto de eventos económicos**:
# - Se analizó el impacto de la crisis de 2008 (estancamiento y caída del 10%)
# - Se analizó el impacto de COVID-19 (resiliencia y recuperación rápida)
# - Se cuantificaron las variaciones interanuales durante estos períodos
# - Se identificaron diferencias en la respuesta del sector ante crisis económicas vs sanitarias
#
# ✅ **Objetivo 5 - Documentación y organización**:
# - Proceso documentado paso a paso en 3 notebooks modulares
# - Código limpio y organizado en funciones reutilizables (`src/cleaning.py` y `src/visualization.py`)
# - Justificación de decisiones tomadas en cada fase
# - Visualizaciones claras y explicativas
# - Estructura de proyecto profesional y reproducible

# %% [markdown]
# ### 8.5 Reflexiones finales
#
# Este análisis exploratorio ha permitido obtener una **visión completa y fundamentada** de la evolución de la inversión en I+D en España durante las últimas dos décadas y media.
#
# **Principales conclusiones:**
#
# 1. **Tendencia positiva general**: A pesar de las crisis económicas, la inversión en I+D ha crecido significativamente, demostrando el compromiso creciente con la innovación y el desarrollo tecnológico.
#
# 2. **Vulnerabilidad ante crisis económicas**: La crisis financiera de 2008 tuvo un impacto más severo y prolongado (5 años de descenso) que la pandemia de COVID-19 (recuperación en 1 año), sugiriendo que las crisis económicas afectan más al I+D que las crisis sanitarias.
#
# 3. **Liderazgo empresarial**: El sector empresarial es el principal ejecutor y financiador de I+D, lo que indica un modelo de innovación liderado por el sector privado, típico de economías desarrolladas.
#
# 4. **Rol de la Enseñanza Superior**: La universidad ha incrementado significativamente su participación, consolidándose como pilar fundamental del sistema de I+D español junto con las empresas.
#
# 5. **Recuperación reciente**: El período 2014-2024 muestra una recuperación sostenida que ha llevado la inversión a máximos históricos, superando ampliamente los niveles pre-crisis de 2008.
#
# 6. **Internacionalización**: El crecimiento de la financiación del "Resto del Mundo" (≈9%) indica una creciente internacionalización de la I+D española y su integración en redes globales de investigación.
#
# **Posibles líneas de análisis futuro:**
# - Análisis de eficiencia: relación entre inversión en I+D y resultados (patentes, publicaciones, innovaciones)
# - Comparativa internacional: posición de España respecto a otros países europeos (% del PIB en I+D)
# - Análisis por comunidades autónomas (distribución territorial del I+D)
# - Relación entre inversión en I+D y crecimiento económico (correlación con PIB)
# - Análisis predictivo: proyección de la inversión en I+D para los próximos 5-10 años
# - Análisis sectorial detallado: ¿qué sectores económicos invierten más en I+D?
#
# **📊 Fin del análisis exploratorio**
#
# **Proyecto:** Análisis de la inversión en I+D en España (2000-2024)
# **Fuente:** Instituto Nacional de Estadística (INE)
# **Estructura:** 3 notebooks modulares + 2 módulos Python reutilizables
# **Período analizado:** 2000-2024 (25 años)
